# %%
#Import required libraries
import numpy as np
np.random.seed(42) # replace 42 with any integer value
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.datasets import make_moons, make_circles,make_blobs
from sklearn.inspection import DecisionBoundaryDisplay
# Import Unsupervised outlier detection models from the pyod package
from pyod.models.lof import LOF
from pyod.models.pca import PCA
from pyod.models.ocsvm import OCSVM
from pyod.models.cblof import CBLOF
from pyod.models.cof import COF
from pyod.models.hbos import HBOS
from pyod.models.knn import KNN
from pyod.models.sod import SOD
from pyod.models.copod import COPOD
from pyod.models.ecod import ECOD
from pyod.models.gmm import GMM
from pyod.models.iforest import IForest
from pyod.models.loda import LODA
from pyod.models.deep_svdd import DeepSVDD
# Create a list of names corresponding to the outlier detection models
names = [
    "LOF",
    "PCA",
    "OCSVM",
    "CBLOF",
    "COF",
    "HBOS",
    "KNN",
    "SOD",
    "COPOD",
    "ECOD",
    "GMM",
    "IForest",
    "LODA",
    "DeepSVDD",
   
]
# Create a list of outlier detection classifiers
classifiers = [
   
    LOF(),
    PCA(),
    OCSVM(),
    CBLOF(),
    COF(),
    HBOS(),
    KNN(),
    SOD(),
    COPOD(),
    ECOD(),
    GMM(),
    IForest(),
    LODA(),
    DeepSVDD(),
]

# Create a list of datasets
datasets = [make_blobs(n_samples=1500, n_features=2, centers=2, random_state=42),
            make_circles(n_samples=1500,noise=0.01, factor=0.5, random_state=42),
            make_moons(n_samples=1500,noise=0.05, random_state=42),]

# Set the figure size and create a new figure
figure = plt.figure(figsize=(27,9))
# Initialize a counter variable for the subplots
i = 1
# Iterate over the datasets
for ds_cnt, ds in enumerate(datasets):
     # Preprocess the dataset and split it into training and test parts
    X, y = ds
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, random_state=42
    )
    # Determine the minimum and maximum values for the x and y axes
    x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
    y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5

    # # Create a color map and a bright version of the same color map
    cm = plt.cm.PuBu
    cm_bright = ListedColormap(["#FF8C00", "#483D8B"])

    ax = plt.subplot(len(datasets), len(classifiers) + 1, i)
    if ds_cnt == 0:
        ax.set_title("Input data")
    # Plot the training points in the subplot
    ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright, edgecolors="k")
    # Plot the testing points in the subplot
    ax.scatter(
        X_test[:, 0], X_test[:, 1], c=y_test, cmap=cm_bright, alpha=0.6, edgecolors="k"
    )
    ax.set_xlim(x_min, x_max)
    ax.set_ylim(y_min, y_max)
    ax.set_xticks(())
    ax.set_yticks(())
    i += 1

    # Loop through each classifier and create a subplot for the classifier's output
    for name, clf in zip(names, classifiers):
        ax = plt.subplot(len(datasets), len(classifiers) + 1, i)
          # Create a pipeline with a StandardScaler and the classifier
        clf = make_pipeline(StandardScaler(), clf)
        # Fit the pipeline to the training data
        clf.fit(X_train)
        # Get the outlier score by using the decision function values for the training data
        score = clf.decision_function(X_train)
        # Create a decision boundary display for the classifie
        DecisionBoundaryDisplay.from_estimator(
            clf, X, cmap=cm, alpha=0.8, ax=ax, eps=0.5
        )

       # Plot the training points 
        ax.scatter(
            X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright, edgecolors="k"
        )
        # Plot the testing points 
        ax.scatter(
            X_test[:, 0],
            X_test[:, 1],
            c=y_test,
            cmap=cm_bright,
            edgecolors="k",
            alpha=0.6,
        )

        ax.set_xlim(x_min, x_max)
        ax.set_ylim(y_min, y_max)
        ax.set_xticks(())
        ax.set_yticks(())
        # Set the title of the subplot to the name of the classifier
        if ds_cnt == 0:
            ax.set_title(name)
         # Display the score of the classifier as text in the top right corner of the subplot
        ax.text(
            x_max - 0.3,
            y_min + 0.3,
            ("%.2f" % score[0]).lstrip("0"),
            size=15,
            horizontalalignment="right",
        )
        i += 1
#Adjust the layout of the subplots to optimize spacing and display the plot
plt.tight_layout()
plt.show()
# Out:
# 33/33 [==============================] - 0s 1ms/step
# Model: "model_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_26 (InputLayer)       [(None, 2)]               0
#
#  dense_25 (Dense)            (None, 64)                128
#
#  net_output (Dense)          (None, 32)                2048
#
#  tf.math.subtract_25 (TFOpLa  (None, 32)               0
#  mbda)
#
#  tf.math.pow_25 (TFOpLambda)  (None, 32)               0
#
#  tf.math.reduce_sum_25 (TFOp  (None,)                  0
#  Lambda)
#
#  tf.math.reduce_mean_25 (TFO  ()                       0
#  pLambda)
#
#  tf.__operators__.add_25 (TF  ()                       0
#  OpLambda)
#
#  add_loss_25 (AddLoss)       ()                        0
#
# =================================================================
# Total params: 2,176
# Trainable params: 2,176
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 30/30 [==============================] - 1s 6ms/step - loss: 0.5759 - val_loss: 0.4027
# Epoch 2/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3730 - val_loss: 0.3341
# Epoch 3/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3166 - val_loss: 0.2800
# Epoch 4/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2691 - val_loss: 0.2539
# Epoch 5/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2400 - val_loss: 0.2122
# Epoch 6/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1965 - val_loss: 0.1744
# Epoch 7/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1592 - val_loss: 0.1514
# Epoch 8/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1399 - val_loss: 0.1337
# Epoch 9/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1264 - val_loss: 0.1166
# Epoch 10/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1116 - val_loss: 0.1103
# Epoch 11/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1072 - val_loss: 0.1069
# Epoch 12/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1046 - val_loss: 0.1050
# Epoch 13/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1025 - val_loss: 0.1029
# Epoch 14/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1006 - val_loss: 0.1013
# Epoch 15/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0991 - val_loss: 0.1000
# Epoch 16/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0982 - val_loss: 0.0988
# Epoch 17/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0970 - val_loss: 0.0980
# Epoch 18/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0959 - val_loss: 0.0972
# Epoch 19/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0954 - val_loss: 0.0964
# Epoch 20/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 21/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0899 - val_loss: 0.0907
# Epoch 22/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0874 - val_loss: 0.0863
# Epoch 23/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0848 - val_loss: 0.0854
# Epoch 24/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0831 - val_loss: 0.0810
# Epoch 25/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0797 - val_loss: 0.0802
# Epoch 26/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0787 - val_loss: 0.0798
# Epoch 27/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0784 - val_loss: 0.0799
# Epoch 28/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0779 - val_loss: 0.0794
# Epoch 29/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0775 - val_loss: 0.0789
# Epoch 30/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0773 - val_loss: 0.0788
# Epoch 31/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0772 - val_loss: 0.0785
# Epoch 32/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0769 - val_loss: 0.0788
# Epoch 33/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0767 - val_loss: 0.0800
# Epoch 34/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0770 - val_loss: 0.0781
# Epoch 35/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0760 - val_loss: 0.0776
# Epoch 36/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0759 - val_loss: 0.0776
# Epoch 37/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0757 - val_loss: 0.0778
# Epoch 38/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0754 - val_loss: 0.0777
# Epoch 39/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0751 - val_loss: 0.0778
# Epoch 40/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0751 - val_loss: 0.0766
# Epoch 41/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0747 - val_loss: 0.0781
# Epoch 42/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0744 - val_loss: 0.0767
# Epoch 43/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0744 - val_loss: 0.0763
# Epoch 44/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0744 - val_loss: 0.0764
# Epoch 45/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0743 - val_loss: 0.0763
# Epoch 46/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0736 - val_loss: 0.0769
# Epoch 47/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0744 - val_loss: 0.0757
# Epoch 48/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0737 - val_loss: 0.0760
# Epoch 49/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0734 - val_loss: 0.0759
# Epoch 50/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0736 - val_loss: 0.0754
# Epoch 51/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0733 - val_loss: 0.0756
# Epoch 52/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0738 - val_loss: 0.0762
# Epoch 53/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0737 - val_loss: 0.0756
# Epoch 54/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0735 - val_loss: 0.0751
# Epoch 55/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0755
# Epoch 56/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0730 - val_loss: 0.0757
# Epoch 57/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0728 - val_loss: 0.0749
# Epoch 58/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0729 - val_loss: 0.0748
# Epoch 59/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0726 - val_loss: 0.0746
# Epoch 60/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0729 - val_loss: 0.0751
# Epoch 61/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0725 - val_loss: 0.0745
# Epoch 62/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0727 - val_loss: 0.0763
# Epoch 63/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0728 - val_loss: 0.0743
# Epoch 64/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0725 - val_loss: 0.0758
# Epoch 65/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0722 - val_loss: 0.0744
# Epoch 66/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0722 - val_loss: 0.0760
# Epoch 67/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0723 - val_loss: 0.0752
# Epoch 68/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0720 - val_loss: 0.0748
# Epoch 69/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0726 - val_loss: 0.0743
# Epoch 70/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0719 - val_loss: 0.0746
# Epoch 71/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0720 - val_loss: 0.0741
# Epoch 72/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0718 - val_loss: 0.0741
# Epoch 73/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0719 - val_loss: 0.0740
# Epoch 74/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0714 - val_loss: 0.0739
# Epoch 75/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0716 - val_loss: 0.0745
# Epoch 76/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0719 - val_loss: 0.0755
# Epoch 77/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0719 - val_loss: 0.0739
# Epoch 78/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0716 - val_loss: 0.0739
# Epoch 79/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0715 - val_loss: 0.0747
# Epoch 80/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0720 - val_loss: 0.0746
# Epoch 81/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0717 - val_loss: 0.0740
# Epoch 82/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0717 - val_loss: 0.0738
# Epoch 83/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0715 - val_loss: 0.0737
# Epoch 84/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0714 - val_loss: 0.0740
# Epoch 85/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0715 - val_loss: 0.0754
# Epoch 86/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0719 - val_loss: 0.0738
# Epoch 87/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0714 - val_loss: 0.0745
# Epoch 88/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0718 - val_loss: 0.0739
# Epoch 89/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0714 - val_loss: 0.0741
# Epoch 90/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0716 - val_loss: 0.0748
# Epoch 91/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0718 - val_loss: 0.0737
# Epoch 92/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0711 - val_loss: 0.0755
# Epoch 93/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0718 - val_loss: 0.0734
# Epoch 94/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0713 - val_loss: 0.0744
# Epoch 95/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0720 - val_loss: 0.0753
# Epoch 96/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0714 - val_loss: 0.0743
# Epoch 97/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0712 - val_loss: 0.0741
# Epoch 98/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0714 - val_loss: 0.0742
# Epoch 99/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0710 - val_loss: 0.0734
# Epoch 100/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0708 - val_loss: 0.0734
# 33/33 [==============================] - 0s 875us/step
# 33/33 [==============================] - 0s 999us/step
# 313/313 [==============================] - 0s 937us/step
# Model: "model_33"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_27 (InputLayer)       [(None, 2)]               0
#
#  dense_26 (Dense)            (None, 64)                128
#
#  net_output (Dense)          (None, 32)                2048
#
#  tf.math.subtract_26 (TFOpLa  (None, 32)               0
#  mbda)
#
#  tf.math.pow_26 (TFOpLambda)  (None, 32)               0
#
#  tf.math.reduce_sum_26 (TFOp  (None,)                  0
#  Lambda)
#
#  tf.math.reduce_mean_26 (TFO  ()                       0
#  pLambda)
#
#  tf.__operators__.add_26 (TF  ()                       0
#  OpLambda)
#
#  add_loss_26 (AddLoss)       ()                        0
#
# =================================================================
# Total params: 2,176
# Trainable params: 2,176
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 30/30 [==============================] - 1s 6ms/step - loss: 0.6739 - val_loss: 0.5039
# Epoch 2/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4225 - val_loss: 0.3667
# Epoch 3/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3159 - val_loss: 0.2812
# Epoch 4/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2472 - val_loss: 0.2260
# Epoch 5/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2065 - val_loss: 0.1955
# Epoch 6/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1852 - val_loss: 0.1764
# Epoch 7/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1700 - val_loss: 0.1636
# Epoch 8/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1587 - val_loss: 0.1535
# Epoch 9/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1503 - val_loss: 0.1458
# Epoch 10/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1429 - val_loss: 0.1396
# Epoch 11/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1374 - val_loss: 0.1343
# Epoch 12/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1329 - val_loss: 0.1305
# Epoch 13/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1290 - val_loss: 0.1266
# Epoch 14/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1259 - val_loss: 0.1243
# Epoch 15/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1237 - val_loss: 0.1216
# Epoch 16/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1218 - val_loss: 0.1201
# Epoch 17/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1202 - val_loss: 0.1185
# Epoch 18/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1187 - val_loss: 0.1172
# Epoch 19/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1176 - val_loss: 0.1163
# Epoch 20/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1169 - val_loss: 0.1160
# Epoch 21/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1158 - val_loss: 0.1149
# Epoch 22/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1154 - val_loss: 0.1145
# Epoch 23/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1146 - val_loss: 0.1133
# Epoch 24/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1140 - val_loss: 0.1137
# Epoch 25/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1135 - val_loss: 0.1124
# Epoch 26/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1130 - val_loss: 0.1120
# Epoch 27/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1124 - val_loss: 0.1112
# Epoch 28/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1123 - val_loss: 0.1117
# Epoch 29/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1120 - val_loss: 0.1111
# Epoch 30/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1111 - val_loss: 0.1112
# Epoch 31/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1117 - val_loss: 0.1109
# Epoch 32/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1114 - val_loss: 0.1097
# Epoch 33/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1107 - val_loss: 0.1105
# Epoch 34/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1108 - val_loss: 0.1104
# Epoch 35/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1105 - val_loss: 0.1095
# Epoch 36/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1104 - val_loss: 0.1089
# Epoch 37/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1101 - val_loss: 0.1088
# Epoch 38/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1106 - val_loss: 0.1088
# Epoch 39/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1099 - val_loss: 0.1092
# Epoch 40/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1101 - val_loss: 0.1098
# Epoch 41/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1094 - val_loss: 0.1087
# Epoch 42/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1093 - val_loss: 0.1081
# Epoch 43/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1094 - val_loss: 0.1084
# Epoch 44/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1097 - val_loss: 0.1080
# Epoch 45/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1091 - val_loss: 0.1090
# Epoch 46/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1088 - val_loss: 0.1075
# Epoch 47/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1090 - val_loss: 0.1074
# Epoch 48/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1089 - val_loss: 0.1077
# Epoch 49/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1088 - val_loss: 0.1077
# Epoch 50/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1084 - val_loss: 0.1074
# Epoch 51/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1083 - val_loss: 0.1080
# Epoch 52/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1084 - val_loss: 0.1080
# Epoch 53/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1086 - val_loss: 0.1072
# Epoch 54/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1089 - val_loss: 0.1073
# Epoch 55/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1081 - val_loss: 0.1074
# Epoch 56/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1079 - val_loss: 0.1077
# Epoch 57/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1078 - val_loss: 0.1068
# Epoch 58/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1081 - val_loss: 0.1068
# Epoch 59/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1074 - val_loss: 0.1065
# Epoch 60/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1076 - val_loss: 0.1075
# Epoch 61/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1080 - val_loss: 0.1065
# Epoch 62/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1081 - val_loss: 0.1072
# Epoch 63/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1075 - val_loss: 0.1075
# Epoch 64/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1075 - val_loss: 0.1067
# Epoch 65/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1079 - val_loss: 0.1069
# Epoch 66/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1077 - val_loss: 0.1085
# Epoch 67/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1080 - val_loss: 0.1066
# Epoch 68/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1073 - val_loss: 0.1073
# Epoch 69/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1075 - val_loss: 0.1066
# Epoch 70/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1070 - val_loss: 0.1061
# Epoch 71/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1072 - val_loss: 0.1069
# Epoch 72/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1076 - val_loss: 0.1057
# Epoch 73/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1073 - val_loss: 0.1069
# Epoch 74/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1075 - val_loss: 0.1070
# Epoch 75/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1070 - val_loss: 0.1086
# Epoch 76/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1069 - val_loss: 0.1073
# Epoch 77/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1074 - val_loss: 0.1079
# Epoch 78/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1072 - val_loss: 0.1065
# Epoch 79/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1073 - val_loss: 0.1054
# Epoch 80/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1068 - val_loss: 0.1060
# Epoch 81/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1072 - val_loss: 0.1061
# Epoch 82/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1072 - val_loss: 0.1061
# Epoch 83/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1072 - val_loss: 0.1067
# Epoch 84/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1065 - val_loss: 0.1062
# Epoch 85/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1070 - val_loss: 0.1065
# Epoch 86/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1070 - val_loss: 0.1067
# Epoch 87/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1067 - val_loss: 0.1055
# Epoch 88/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1067 - val_loss: 0.1058
# Epoch 89/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1071 - val_loss: 0.1061
# Epoch 90/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1069 - val_loss: 0.1054
# Epoch 91/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1063 - val_loss: 0.1060
# Epoch 92/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1077 - val_loss: 0.1050
# Epoch 93/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1068 - val_loss: 0.1056
# Epoch 94/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1075 - val_loss: 0.1057
# Epoch 95/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1067 - val_loss: 0.1062
# Epoch 96/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1070 - val_loss: 0.1058
# Epoch 97/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1068 - val_loss: 0.1060
# Epoch 98/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1064 - val_loss: 0.1055
# Epoch 99/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1063 - val_loss: 0.1053
# Epoch 100/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1065 - val_loss: 0.1057
# 33/33 [==============================] - 0s 975us/step
# 33/33 [==============================] - 0s 976us/step
# 313/313 [==============================] - 0s 963us/step
# Model: "model_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_28 (InputLayer)       [(None, 2)]               0
#
#  dense_27 (Dense)            (None, 64)                128
#
#  net_output (Dense)          (None, 32)                2048
#
#  tf.math.subtract_27 (TFOpLa  (None, 32)               0
#  mbda)
#
#  tf.math.pow_27 (TFOpLambda)  (None, 32)               0
#
#  tf.math.reduce_sum_27 (TFOp  (None,)                  0
#  Lambda)
#
#  tf.math.reduce_mean_27 (TFO  ()                       0
#  pLambda)
#
#  tf.__operators__.add_27 (TF  ()                       0
#  OpLambda)
#
#  add_loss_27 (AddLoss)       ()                        0
#
# =================================================================
# Total params: 2,176
# Trainable params: 2,176
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 30/30 [==============================] - 1s 6ms/step - loss: 0.5344 - val_loss: 0.4368
# Epoch 2/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3654 - val_loss: 0.3009
# Epoch 3/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2716 - val_loss: 0.2375
# Epoch 4/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2236 - val_loss: 0.1947
# Epoch 5/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1894 - val_loss: 0.1696
# Epoch 6/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1697 - val_loss: 0.1532
# Epoch 7/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1570 - val_loss: 0.1426
# Epoch 8/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1481 - val_loss: 0.1342
# Epoch 9/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1413 - val_loss: 0.1279
# Epoch 10/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1360 - val_loss: 0.1225
# Epoch 11/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1315 - val_loss: 0.1189
# Epoch 12/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1283 - val_loss: 0.1150
# Epoch 13/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1252 - val_loss: 0.1123
# Epoch 14/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1234 - val_loss: 0.1103
# Epoch 15/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1216 - val_loss: 0.1086
# Epoch 16/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1200 - val_loss: 0.1076
# Epoch 17/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1186 - val_loss: 0.1060
# Epoch 18/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1179 - val_loss: 0.1047
# Epoch 19/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1170 - val_loss: 0.1036
# Epoch 20/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1159 - val_loss: 0.1031
# Epoch 21/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1155 - val_loss: 0.1022
# Epoch 22/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1149 - val_loss: 0.1022
# Epoch 23/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1147 - val_loss: 0.1014
# Epoch 24/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1139 - val_loss: 0.1014
# Epoch 25/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1138 - val_loss: 0.1004
# Epoch 26/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1134 - val_loss: 0.1015
# Epoch 27/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1128 - val_loss: 0.0998
# Epoch 28/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1129 - val_loss: 0.0998
# Epoch 29/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1123 - val_loss: 0.0995
# Epoch 30/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1120 - val_loss: 0.0985
# Epoch 31/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1119 - val_loss: 0.0982
# Epoch 32/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1119 - val_loss: 0.0982
# Epoch 33/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1116 - val_loss: 0.0980
# Epoch 34/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1115 - val_loss: 0.0980
# Epoch 35/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1109 - val_loss: 0.0976
# Epoch 36/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1110 - val_loss: 0.0986
# Epoch 37/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1111 - val_loss: 0.0975
# Epoch 38/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1113 - val_loss: 0.0971
# Epoch 39/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1109 - val_loss: 0.0981
# Epoch 40/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1106 - val_loss: 0.0972
# Epoch 41/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1111 - val_loss: 0.0969
# Epoch 42/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1107 - val_loss: 0.0987
# Epoch 43/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1104 - val_loss: 0.0977
# Epoch 44/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1105 - val_loss: 0.0971
# Epoch 45/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1099 - val_loss: 0.0975
# Epoch 46/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1103 - val_loss: 0.0979
# Epoch 47/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1104 - val_loss: 0.0979
# Epoch 48/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1097 - val_loss: 0.0965
# Epoch 49/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1097 - val_loss: 0.0967
# Epoch 50/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1096 - val_loss: 0.0976
# Epoch 51/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1097 - val_loss: 0.0955
# Epoch 52/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1095 - val_loss: 0.0982
# Epoch 53/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1099 - val_loss: 0.0971
# Epoch 54/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1096 - val_loss: 0.0963
# Epoch 55/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1096 - val_loss: 0.0967
# Epoch 56/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1098 - val_loss: 0.0962
# Epoch 57/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1088 - val_loss: 0.0979
# Epoch 58/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1095 - val_loss: 0.0972
# Epoch 59/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1088 - val_loss: 0.0961
# Epoch 60/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1093 - val_loss: 0.0951
# Epoch 61/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1090 - val_loss: 0.0968
# Epoch 62/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1091 - val_loss: 0.0959
# Epoch 63/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1096 - val_loss: 0.0967
# Epoch 64/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1093 - val_loss: 0.0966
# Epoch 65/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1097 - val_loss: 0.0961
# Epoch 66/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1094 - val_loss: 0.0974
# Epoch 67/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1087 - val_loss: 0.0950
# Epoch 68/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1090 - val_loss: 0.0990
# Epoch 69/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1097 - val_loss: 0.0959
# Epoch 70/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1088 - val_loss: 0.0960
# Epoch 71/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1095 - val_loss: 0.0970
# Epoch 72/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1086 - val_loss: 0.0952
# Epoch 73/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1094 - val_loss: 0.0952
# Epoch 74/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1084 - val_loss: 0.0961
# Epoch 75/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1087 - val_loss: 0.0951
# Epoch 76/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1085 - val_loss: 0.0948
# Epoch 77/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1083 - val_loss: 0.0966
# Epoch 78/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1089 - val_loss: 0.0951
# Epoch 79/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1085 - val_loss: 0.0959
# Epoch 80/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1084 - val_loss: 0.0946
# Epoch 81/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1088 - val_loss: 0.0959
# Epoch 82/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1085 - val_loss: 0.0950
# Epoch 83/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1083 - val_loss: 0.0953
# Epoch 84/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1084 - val_loss: 0.0961
# Epoch 85/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1085 - val_loss: 0.0942
# Epoch 86/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1082 - val_loss: 0.0952
# Epoch 87/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1089 - val_loss: 0.0949
# Epoch 88/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1082 - val_loss: 0.0947
# Epoch 89/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1082 - val_loss: 0.0965
# Epoch 90/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1089 - val_loss: 0.0945
# Epoch 91/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1083 - val_loss: 0.0952
# Epoch 92/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1084 - val_loss: 0.0962
# Epoch 93/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1081 - val_loss: 0.0968
# Epoch 94/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1086 - val_loss: 0.0946
# Epoch 95/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1089 - val_loss: 0.0951
# Epoch 96/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1082 - val_loss: 0.0953
# Epoch 97/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1082 - val_loss: 0.0974
# Epoch 98/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1084 - val_loss: 0.0960
# Epoch 99/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1078 - val_loss: 0.0962
# Epoch 100/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1079 - val_loss: 0.0946
# 33/33 [==============================] - 0s 1ms/step
# 33/33 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
