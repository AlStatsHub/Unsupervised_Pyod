# %%
import numpy as np
np.random.seed(42) # replace 42 with any integer value
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.datasets import make_moons, make_circles, make_classification,make_blobs
from sklearn.inspection import DecisionBoundaryDisplay
from pyod.models.lof import LOF
from pyod.models.pca import PCA
from pyod.models.ocsvm import OCSVM
from pyod.models.cblof import CBLOF
from pyod.models.cof import COF
from pyod.models.hbos import HBOS
from pyod.models.knn import KNN
from pyod.models.sod import SOD
from pyod.models.copod import COPOD
from pyod.models.ecod import ECOD
from pyod.models.gmm import GMM
from pyod.models.iforest import IForest
from pyod.models.loda import LODA
from pyod.models.deep_svdd import DeepSVDD

names = [
    "LOF",
    "PCA",
    "OCSVM",
    "CBLOF",
    "COF",
    "HBOS",
    "KNN",
    "SOD",
    "COPOD",
    "ECOD",
    "GMM",
    "IForest",
    "LODA",
    "DeepSVDD",
   
]

classifiers = [
   
    LOF(),
    PCA(),
    OCSVM(),
    CBLOF(),
    COF(),
    HBOS(),
    KNN(),
    SOD(),
    COPOD(),
    ECOD(),
    GMM(),
    IForest(),
    LODA(),
    DeepSVDD(),
]

X, y = make_moons(n_samples=1500,noise=0.05, random_state=42)
rng = np.random.RandomState(2)
X += 2 * rng.uniform(size=X.shape)
linearly_separable = (X, y)

datasets = [
    make_blobs(n_samples=1500, n_features=2, centers=2, random_state=42),
    make_circles(n_samples=1500,noise=0.01, factor=0.5, random_state=42),
    linearly_separable,
]

figure = plt.figure(figsize=(27,9))
i = 1
# iterate over datasets
for ds_cnt, ds in enumerate(datasets):
    # preprocess dataset, split into training and test part
    X, y = ds
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, random_state=42
    )

    x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
    y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5

    # just plot the dataset first
    cm = plt.cm.PuBu
    cm_bright = ListedColormap(["#FF8C00", "#483D8B"])

    ax = plt.subplot(len(datasets), len(classifiers) + 1, i)
    if ds_cnt == 0:
        ax.set_title("Input data")
    # Plot the training points
    ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright, edgecolors="k")
    # Plot the testing points
    ax.scatter(
        X_test[:, 0], X_test[:, 1], c=y_test, cmap=cm_bright, alpha=0.6, edgecolors="k"
    )
    ax.set_xlim(x_min, x_max)
    ax.set_ylim(y_min, y_max)
    ax.set_xticks(())
    ax.set_yticks(())
    i += 1

    # iterate over classifiers
    for name, clf in zip(names, classifiers):
        ax = plt.subplot(len(datasets), len(classifiers) + 1, i)

        clf = make_pipeline(StandardScaler(), clf)
        clf.fit(X_train,)
        score = clf.decision_function(X_train)
        DecisionBoundaryDisplay.from_estimator(
            clf, X, cmap=cm, alpha=0.8, ax=ax, eps=0.5
        )

        # Plot the training points
        ax.scatter(
            X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright, edgecolors="k"
        )
        # Plot the testing points
        ax.scatter(
            X_test[:, 0],
            X_test[:, 1],
            c=y_test,
            cmap=cm_bright,
            edgecolors="k",
            alpha=0.6,
        )

        ax.set_xlim(x_min, x_max)
        ax.set_ylim(y_min, y_max)
        ax.set_xticks(())
        ax.set_yticks(())
        if ds_cnt == 0:
            ax.set_title(name)
        ax.text(
            x_max - 0.3,
            y_min + 0.3,
            ("%.2f" % score[0]).lstrip("0"),
            size=15,
            horizontalalignment="right",
        )
        i += 1

plt.tight_layout()
plt.show()
# Out:
# 33/33 [==============================] - 0s 2ms/step
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_1 (Dense)             (None, 64)                128
#
#  net_output (Dense)          (None, 32)                2048
#
#  tf.math.subtract_1 (TFOpLam  (None, 32)               0
#  bda)
#
#  tf.math.pow_1 (TFOpLambda)  (None, 32)                0
#
#  tf.math.reduce_sum_1 (TFOpL  (None,)                  0
#  ambda)
#
#  tf.math.reduce_mean_1 (TFOp  ()                       0
#  Lambda)
#
#  tf.__operators__.add_1 (TFO  ()                       0
#  pLambda)
#
#  add_loss_1 (AddLoss)        ()                        0
#
# =================================================================
# Total params: 2,176
# Trainable params: 2,176
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 30/30 [==============================] - 2s 28ms/step - loss: 0.5874 - val_loss: 0.4710
# Epoch 2/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.4495 - val_loss: 0.4158
# Epoch 3/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.3934 - val_loss: 0.3609
# Epoch 4/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.3418 - val_loss: 0.3196
# Epoch 5/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.3049 - val_loss: 0.2638
# Epoch 6/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.2389 - val_loss: 0.2229
# Epoch 7/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2087 - val_loss: 0.1878
# Epoch 8/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1699 - val_loss: 0.1612
# Epoch 9/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1545 - val_loss: 0.1515
# Epoch 10/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1474 - val_loss: 0.1460
# Epoch 11/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1424 - val_loss: 0.1419
# Epoch 12/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1386 - val_loss: 0.1385
# Epoch 13/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1326 - val_loss: 0.1314
# Epoch 14/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1288 - val_loss: 0.1291
# Epoch 15/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1267 - val_loss: 0.1272
# Epoch 16/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1247 - val_loss: 0.1231
# Epoch 17/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1158 - val_loss: 0.1126
# Epoch 18/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1099 - val_loss: 0.1102
# Epoch 19/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1086 - val_loss: 0.1098
# Epoch 20/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1079 - val_loss: 0.1085
# Epoch 21/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1072 - val_loss: 0.1079
# Epoch 22/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1064 - val_loss: 0.1081
# Epoch 23/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1060 - val_loss: 0.1074
# Epoch 24/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1051 - val_loss: 0.1083
# Epoch 25/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1053 - val_loss: 0.1060
# Epoch 26/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1042 - val_loss: 0.1055
# Epoch 27/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1038 - val_loss: 0.1054
# Epoch 28/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1043 - val_loss: 0.1058
# Epoch 29/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1032 - val_loss: 0.1063
# Epoch 30/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1033 - val_loss: 0.1048
# Epoch 31/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1029 - val_loss: 0.1049
# Epoch 32/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1024 - val_loss: 0.1040
# Epoch 33/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1023 - val_loss: 0.1050
# Epoch 34/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1022 - val_loss: 0.1034
# Epoch 35/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1021 - val_loss: 0.1033
# Epoch 36/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1013 - val_loss: 0.1041
# Epoch 37/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1012 - val_loss: 0.1032
# Epoch 38/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1010 - val_loss: 0.1031
# Epoch 39/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1009 - val_loss: 0.1025
# Epoch 40/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1007 - val_loss: 0.1035
# Epoch 41/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1007 - val_loss: 0.1023
# Epoch 42/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1004 - val_loss: 0.1027
# Epoch 43/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1003 - val_loss: 0.1023
# Epoch 44/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1001 - val_loss: 0.1031
# Epoch 45/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1002 - val_loss: 0.1024
# Epoch 46/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1001 - val_loss: 0.1023
# Epoch 47/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0998 - val_loss: 0.1016
# Epoch 48/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0998 - val_loss: 0.1018
# Epoch 49/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0998 - val_loss: 0.1013
# Epoch 50/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0995 - val_loss: 0.1013
# Epoch 51/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0993 - val_loss: 0.1019
# Epoch 52/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0995 - val_loss: 0.1014
# Epoch 53/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0993 - val_loss: 0.1014
# Epoch 54/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0996 - val_loss: 0.1012
# Epoch 55/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0995 - val_loss: 0.1010
# Epoch 56/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0993 - val_loss: 0.1013
# Epoch 57/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0989 - val_loss: 0.1016
# Epoch 58/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0987 - val_loss: 0.1012
# Epoch 59/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0994 - val_loss: 0.1012
# Epoch 60/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0984 - val_loss: 0.1013
# Epoch 61/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0991 - val_loss: 0.1017
# Epoch 62/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0986 - val_loss: 0.1010
# Epoch 63/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0987 - val_loss: 0.1006
# Epoch 64/100
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0985 - val_loss: 0.1008
# Epoch 65/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0988 - val_loss: 0.1005
# Epoch 66/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0983 - val_loss: 0.1012
# Epoch 67/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0985 - val_loss: 0.1002
# Epoch 68/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0982 - val_loss: 0.1003
# Epoch 69/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0981 - val_loss: 0.1011
# Epoch 70/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0984 - val_loss: 0.1002
# Epoch 71/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0985 - val_loss: 0.1002
# Epoch 72/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0980 - val_loss: 0.1006
# Epoch 73/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0980 - val_loss: 0.1015
# Epoch 74/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0984 - val_loss: 0.1002
# Epoch 75/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0977 - val_loss: 0.1009
# Epoch 76/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0978 - val_loss: 0.1011
# Epoch 77/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0979 - val_loss: 0.1010
# Epoch 78/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0985 - val_loss: 0.1005
# Epoch 79/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0982 - val_loss: 0.1008
# Epoch 80/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0996 - val_loss: 0.1008
# Epoch 81/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0980 - val_loss: 0.1002
# Epoch 82/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0974 - val_loss: 0.1017
# Epoch 83/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0974 - val_loss: 0.1002
# Epoch 84/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0985 - val_loss: 0.1034
# Epoch 85/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0940 - val_loss: 0.0920
# Epoch 86/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0893 - val_loss: 0.0912
# Epoch 87/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0891 - val_loss: 0.0911
# Epoch 88/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0890 - val_loss: 0.0918
# Epoch 89/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0891 - val_loss: 0.0911
# Epoch 90/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0889 - val_loss: 0.0947
# Epoch 91/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0888 - val_loss: 0.0907
# Epoch 92/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0887 - val_loss: 0.0917
# Epoch 93/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0894 - val_loss: 0.0918
# Epoch 94/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0887 - val_loss: 0.0918
# Epoch 95/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0887 - val_loss: 0.0911
# Epoch 96/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0888 - val_loss: 0.0918
# Epoch 97/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0883 - val_loss: 0.0908
# Epoch 98/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0885 - val_loss: 0.0927
# Epoch 99/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0886 - val_loss: 0.0906
# Epoch 100/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0885 - val_loss: 0.0929
# 33/33 [==============================] - 0s 2ms/step
# 33/33 [==============================] - 0s 2ms/step
# 313/313 [==============================] - 1s 2ms/step
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 2)]               0
#
#  dense_2 (Dense)             (None, 64)                128
#
#  net_output (Dense)          (None, 32)                2048
#
#  tf.math.subtract_2 (TFOpLam  (None, 32)               0
#  bda)
#
#  tf.math.pow_2 (TFOpLambda)  (None, 32)                0
#
#  tf.math.reduce_sum_2 (TFOpL  (None,)                  0
#  ambda)
#
#  tf.math.reduce_mean_2 (TFOp  ()                       0
#  Lambda)
#
#  tf.__operators__.add_2 (TFO  ()                       0
#  pLambda)
#
#  add_loss_2 (AddLoss)        ()                        0
#
# =================================================================
# Total params: 2,176
# Trainable params: 2,176
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 30/30 [==============================] - 1s 12ms/step - loss: 0.6902 - val_loss: 0.5299
# Epoch 2/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4442 - val_loss: 0.3817
# Epoch 3/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3369 - val_loss: 0.3075
# Epoch 4/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.2844 - val_loss: 0.2728
# Epoch 5/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.2571 - val_loss: 0.2462
# Epoch 6/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.2346 - val_loss: 0.2278
# Epoch 7/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2191 - val_loss: 0.2137
# Epoch 8/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2069 - val_loss: 0.2025
# Epoch 9/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1971 - val_loss: 0.1934
# Epoch 10/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1890 - val_loss: 0.1865
# Epoch 11/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1827 - val_loss: 0.1805
# Epoch 12/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1775 - val_loss: 0.1755
# Epoch 13/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1698 - val_loss: 0.1651
# Epoch 14/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1623 - val_loss: 0.1613
# Epoch 15/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1594 - val_loss: 0.1578
# Epoch 16/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1570 - val_loss: 0.1557
# Epoch 17/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1551 - val_loss: 0.1542
# Epoch 18/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1536 - val_loss: 0.1526
# Epoch 19/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1525 - val_loss: 0.1515
# Epoch 20/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1519 - val_loss: 0.1506
# Epoch 21/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1504 - val_loss: 0.1494
# Epoch 22/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1502 - val_loss: 0.1487
# Epoch 23/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1494 - val_loss: 0.1482
# Epoch 24/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1484 - val_loss: 0.1470
# Epoch 25/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1479 - val_loss: 0.1476
# Epoch 26/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1477 - val_loss: 0.1462
# Epoch 27/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1470 - val_loss: 0.1463
# Epoch 28/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1468 - val_loss: 0.1456
# Epoch 29/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1472 - val_loss: 0.1452
# Epoch 30/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1460 - val_loss: 0.1453
# Epoch 31/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1462 - val_loss: 0.1447
# Epoch 32/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1453 - val_loss: 0.1444
# Epoch 33/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1455 - val_loss: 0.1439
# Epoch 34/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1452 - val_loss: 0.1437
# Epoch 35/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1445 - val_loss: 0.1433
# Epoch 36/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1444 - val_loss: 0.1434
# Epoch 37/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1442 - val_loss: 0.1434
# Epoch 38/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1444 - val_loss: 0.1428
# Epoch 39/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1441 - val_loss: 0.1427
# Epoch 40/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1439 - val_loss: 0.1436
# Epoch 41/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1438 - val_loss: 0.1423
# Epoch 42/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1433 - val_loss: 0.1421
# Epoch 43/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1434 - val_loss: 0.1421
# Epoch 44/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1432 - val_loss: 0.1416
# Epoch 45/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1432 - val_loss: 0.1421
# Epoch 46/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1439 - val_loss: 0.1414
# Epoch 47/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1428 - val_loss: 0.1427
# Epoch 48/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1429 - val_loss: 0.1419
# Epoch 49/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1430 - val_loss: 0.1415
# Epoch 50/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1429 - val_loss: 0.1417
# Epoch 51/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1423 - val_loss: 0.1412
# Epoch 52/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1427 - val_loss: 0.1417
# Epoch 53/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1434 - val_loss: 0.1416
# Epoch 54/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1425 - val_loss: 0.1409
# Epoch 55/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1422 - val_loss: 0.1418
# Epoch 56/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1423 - val_loss: 0.1410
# Epoch 57/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1423 - val_loss: 0.1405
# Epoch 58/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1427 - val_loss: 0.1405
# Epoch 59/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1423 - val_loss: 0.1411
# Epoch 60/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1421 - val_loss: 0.1404
# Epoch 61/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1423 - val_loss: 0.1409
# Epoch 62/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1421 - val_loss: 0.1405
# Epoch 63/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1415 - val_loss: 0.1414
# Epoch 64/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1419 - val_loss: 0.1408
# Epoch 65/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1417 - val_loss: 0.1413
# Epoch 66/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1417 - val_loss: 0.1407
# Epoch 67/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1422 - val_loss: 0.1409
# Epoch 68/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1418 - val_loss: 0.1403
# Epoch 69/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1413 - val_loss: 0.1400
# Epoch 70/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1412 - val_loss: 0.1402
# Epoch 71/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1414 - val_loss: 0.1398
# Epoch 72/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1424 - val_loss: 0.1404
# Epoch 73/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1414 - val_loss: 0.1405
# Epoch 74/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1410 - val_loss: 0.1408
# Epoch 75/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1413 - val_loss: 0.1408
# Epoch 76/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1411 - val_loss: 0.1399
# Epoch 77/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1384 - val_loss: 0.1299
# Epoch 78/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1192 - val_loss: 0.1152
# Epoch 79/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1152 - val_loss: 0.1153
# Epoch 80/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1162 - val_loss: 0.1149
# Epoch 81/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1154 - val_loss: 0.1149
# Epoch 82/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1150 - val_loss: 0.1135
# Epoch 83/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1155 - val_loss: 0.1137
# Epoch 84/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1152 - val_loss: 0.1140
# Epoch 85/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1150 - val_loss: 0.1146
# Epoch 86/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1156 - val_loss: 0.1143
# Epoch 87/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1150 - val_loss: 0.1134
# Epoch 88/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1155 - val_loss: 0.1145
# Epoch 89/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1151 - val_loss: 0.1141
# Epoch 90/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1151 - val_loss: 0.1132
# Epoch 91/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1152 - val_loss: 0.1146
# Epoch 92/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1150 - val_loss: 0.1135
# Epoch 93/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1145 - val_loss: 0.1145
# Epoch 94/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1145 - val_loss: 0.1134
# Epoch 95/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1144 - val_loss: 0.1141
# Epoch 96/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1150 - val_loss: 0.1149
# Epoch 97/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1155 - val_loss: 0.1146
# Epoch 98/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1155 - val_loss: 0.1138
# Epoch 99/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1150 - val_loss: 0.1152
# Epoch 100/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1145 - val_loss: 0.1137
# 33/33 [==============================] - 0s 997us/step
# 33/33 [==============================] - 0s 966us/step
# 313/313 [==============================] - 0s 1ms/step
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 2)]               0
#
#  dense_3 (Dense)             (None, 64)                128
#
#  net_output (Dense)          (None, 32)                2048
#
#  tf.math.subtract_3 (TFOpLam  (None, 32)               0
#  bda)
#
#  tf.math.pow_3 (TFOpLambda)  (None, 32)                0
#
#  tf.math.reduce_sum_3 (TFOpL  (None,)                  0
#  ambda)
#
#  tf.math.reduce_mean_3 (TFOp  ()                       0
#  Lambda)
#
#  tf.__operators__.add_3 (TFO  ()                       0
#  pLambda)
#
#  add_loss_3 (AddLoss)        ()                        0
#
# =================================================================
# Total params: 2,176
# Trainable params: 2,176
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 30/30 [==============================] - 1s 17ms/step - loss: 0.7692 - val_loss: 0.5856
# Epoch 2/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4862 - val_loss: 0.4152
# Epoch 3/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.3740 - val_loss: 0.3506
# Epoch 4/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.3313 - val_loss: 0.3231
# Epoch 5/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.3065 - val_loss: 0.3005
# Epoch 6/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.2879 - val_loss: 0.2835
# Epoch 7/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.2687 - val_loss: 0.2658
# Epoch 8/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2563 - val_loss: 0.2569
# Epoch 9/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2479 - val_loss: 0.2477
# Epoch 10/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2404 - val_loss: 0.2419
# Epoch 11/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.2349 - val_loss: 0.2358
# Epoch 12/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.2302 - val_loss: 0.2310
# Epoch 13/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2261 - val_loss: 0.2284
# Epoch 14/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.2229 - val_loss: 0.2258
# Epoch 15/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2209 - val_loss: 0.2232
# Epoch 16/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2184 - val_loss: 0.2203
# Epoch 17/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.2173 - val_loss: 0.2200
# Epoch 18/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.2153 - val_loss: 0.2176
# Epoch 19/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.2134 - val_loss: 0.2162
# Epoch 20/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.2124 - val_loss: 0.2151
# Epoch 21/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.2113 - val_loss: 0.2142
# Epoch 22/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.2111 - val_loss: 0.2128
# Epoch 23/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.2106 - val_loss: 0.2131
# Epoch 24/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2097 - val_loss: 0.2113
# Epoch 25/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.2086 - val_loss: 0.2120
# Epoch 26/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2077 - val_loss: 0.2117
# Epoch 27/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2079 - val_loss: 0.2093
# Epoch 28/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2067 - val_loss: 0.2110
# Epoch 29/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2069 - val_loss: 0.2095
# Epoch 30/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2062 - val_loss: 0.2090
# Epoch 31/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.2061 - val_loss: 0.2090
# Epoch 32/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.2059 - val_loss: 0.2086
# Epoch 33/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.2053 - val_loss: 0.2089
# Epoch 34/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2054 - val_loss: 0.2068
# Epoch 35/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.2055 - val_loss: 0.2085
# Epoch 36/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2022 - val_loss: 0.1998
# Epoch 37/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1977 - val_loss: 0.2012
# Epoch 38/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1975 - val_loss: 0.2022
# Epoch 39/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1966 - val_loss: 0.1991
# Epoch 40/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1967 - val_loss: 0.1993
# Epoch 41/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1962 - val_loss: 0.2003
# Epoch 42/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1975 - val_loss: 0.1984
# Epoch 43/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1969 - val_loss: 0.1997
# Epoch 44/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1962 - val_loss: 0.1994
# Epoch 45/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1964 - val_loss: 0.1977
# Epoch 46/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1959 - val_loss: 0.1986
# Epoch 47/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1962 - val_loss: 0.1978
# Epoch 48/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1961 - val_loss: 0.2001
# Epoch 49/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1966 - val_loss: 0.1976
# Epoch 50/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1955 - val_loss: 0.1998
# Epoch 51/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1947 - val_loss: 0.1980
# Epoch 52/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1951 - val_loss: 0.1990
# Epoch 53/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1960 - val_loss: 0.1974
# Epoch 54/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1950 - val_loss: 0.1968
# Epoch 55/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1955 - val_loss: 0.1997
# Epoch 56/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1958 - val_loss: 0.1976
# Epoch 57/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1956 - val_loss: 0.1974
# Epoch 58/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1947 - val_loss: 0.1969
# Epoch 59/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1949 - val_loss: 0.2004
# Epoch 60/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1951 - val_loss: 0.1981
# Epoch 61/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1942 - val_loss: 0.1966
# Epoch 62/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1940 - val_loss: 0.1982
# Epoch 63/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1950 - val_loss: 0.1985
# Epoch 64/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1949 - val_loss: 0.1966
# Epoch 65/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1943 - val_loss: 0.1991
# Epoch 66/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1950 - val_loss: 0.1984
# Epoch 67/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1949 - val_loss: 0.1961
# Epoch 68/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1941 - val_loss: 0.1996
# Epoch 69/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1942 - val_loss: 0.1973
# Epoch 70/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1948 - val_loss: 0.1977
# Epoch 71/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1943 - val_loss: 0.1983
# Epoch 72/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1944 - val_loss: 0.1981
# Epoch 73/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1944 - val_loss: 0.1965
# Epoch 74/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1945 - val_loss: 0.2007
# Epoch 75/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1940 - val_loss: 0.1975
# Epoch 76/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1941 - val_loss: 0.1991
# Epoch 77/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1932 - val_loss: 0.1962
# Epoch 78/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1931 - val_loss: 0.1968
# Epoch 79/100
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1946 - val_loss: 0.1961
# Epoch 80/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1941 - val_loss: 0.1986
# Epoch 81/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1937 - val_loss: 0.1967
# Epoch 82/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1939 - val_loss: 0.1960
# Epoch 83/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1943 - val_loss: 0.1967
# Epoch 84/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1933 - val_loss: 0.1987
# Epoch 85/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1936 - val_loss: 0.1978
# Epoch 86/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1933 - val_loss: 0.1994
# Epoch 87/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1932 - val_loss: 0.1959
# Epoch 88/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1938 - val_loss: 0.1976
# Epoch 89/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1934 - val_loss: 0.1954
# Epoch 90/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1933 - val_loss: 0.1973
# Epoch 91/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1933 - val_loss: 0.1986
# Epoch 92/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1937 - val_loss: 0.1971
# Epoch 93/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1941 - val_loss: 0.1981
# Epoch 94/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1936 - val_loss: 0.1973
# Epoch 95/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1927 - val_loss: 0.1958
# Epoch 96/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1934 - val_loss: 0.1960
# Epoch 97/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1927 - val_loss: 0.1968
# Epoch 98/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1922 - val_loss: 0.1968
# Epoch 99/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1925 - val_loss: 0.1950
# Epoch 100/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1928 - val_loss: 0.1960
# 33/33 [==============================] - 0s 2ms/step
# 33/33 [==============================] - 0s 2ms/step
# 313/313 [==============================] - 1s 2ms/step
